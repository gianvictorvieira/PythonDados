# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.4'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print("array após somar 10", soma)
# Out:
# array após somar 10 [11 12 13 14 15]

# %%
mult = arr * 10
print("array após Multiplicar 10", mult)
# Out:
# array após somar 10 [10 20 30 40 50]

# %%
media = np.mean(arr)
print("Média do array:", media)
# Out:
# Média do array: 3.0
